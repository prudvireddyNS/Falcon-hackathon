# %%
import requests
from bs4 import BeautifulSoup

def extract_links(url):
    # Send a request to the website
    response = requests.get(url)
    
    # Parse the content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all links
    links = []
    for a_tag in soup.find_all('a', href=True):
        if a_tag['href'].startswith('http'):
            links.append(a_tag['href'])
    
    return links

# Example usage
website_url = 'https://docs.crewai.com/'
all_links = extract_links(website_url)

# Print all links
for link in all_links:
    print(link)
len(all_links)
# Out:
# https://github.com/joaomdmoura/crewai/
# https://github.com/joaomdmoura/crewai/
# https://github.com/joaomdmoura/crewAI-examples/tree/main/trip_planner
# https://github.com/joaomdmoura/crewAI-examples/tree/main/instagram_post
# https://github.com/joaomdmoura/crewAI-examples/tree/main/stock_analysis
# https://github.com/joaomdmoura/crewAI-examples/tree/main/game-builder-crew
# https://github.com/joaomdmoura/crewAI-examples/tree/main/CrewAI-LangGraph
# https://github.com/joaomdmoura/crewAI-examples/tree/main/landing_page_generator
# https://github.com/joaomdmoura/crewAI-examples/tree/main/prep-for-a-meeting
# https://github.com/crewAIInc/crewAI/releases
# https://github.com/joaomdmoura/crewai/edit/main/docs/index.md
# https://github.com/joaomdmoura/crewai/raw/main/docs/index.md
# https://github.com/joaomdmoura/crewAI-examples/tree/main/prep-for-a-meeting
# https://github.com/joaomdmoura/crewAI-examples/tree/main/trip_planner
# https://github.com/joaomdmoura/crewAI-examples/tree/main/instagram_post
# https://github.com/joaomdmoura/crewAI-examples/tree/main/stock_analysis
# https://github.com/joaomdmoura/crewAI-examples/tree/main/game-builder-crew
# https://github.com/joaomdmoura/crewAI-examples/tree/main/CrewAI-LangGraph
# https://github.com/joaomdmoura/crewAI-examples/tree/main/landing_page_generator
# https://squidfunk.github.io/mkdocs-material/
# https://twitter.com/joaomdmoura
# https://github.com/joaomdmoura/crewAI
# 22

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def extract_links(url):
    # Send a request to the website
    response = requests.get(url)
    
    # Parse the content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all links
    links = []
    for a_tag in soup.find_all('a', href=True):
        # Resolve relative URLs
        full_url = urljoin(url, a_tag['href'])
        links.append(full_url)
    
    return links

# Example usage
website_url = 'https://docs.crewai.com/'
all_links = extract_links(website_url)

# Print all links
for link in all_links:
    print(link)
print(len(all_links))
# Out:
# https://docs.crewai.com/#crewai-documentation
# https://docs.crewai.com/
# javascript:void(0)
# https://github.com/joaomdmoura/crewai/
# https://docs.crewai.com/
# https://github.com/joaomdmoura/crewai/
# https://docs.crewai.com/
# https://docs.crewai.com/core-concepts/Agents/
# https://docs.crewai.com/core-concepts/Tasks/
# https://docs.crewai.com/core-concepts/Tools/
# https://docs.crewai.com/core-concepts/Processes/
# https://docs.crewai.com/core-concepts/Crews/
# https://docs.crewai.com/core-concepts/Collaboration/
# https://docs.crewai.com/core-concepts/Training-Crew/
# https://docs.crewai.com/core-concepts/Memory/
# https://docs.crewai.com/core-concepts/Planning/
# https://docs.crewai.com/core-concepts/Testing/
# https://docs.crewai.com/core-concepts/Using-LangChain-Tools/
# https://docs.crewai.com/core-concepts/Using-LlamaIndex-Tools/
# https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project/
# https://docs.crewai.com/how-to/Installing-CrewAI/
# https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off/
# https://docs.crewai.com/how-to/Create-Custom-Tools/
# https://docs.crewai.com/how-to/Sequential/
# https://docs.crewai.com/how-to/Hierarchical/
# https://docs.crewai.com/how-to/Your-Own-Manager-Agent/
# https://docs.crewai.com/how-to/LLM-Connections/
# https://docs.crewai.com/how-to/Customizing-Agents/
# https://docs.crewai.com/how-to/Coding-Agents/
# https://docs.crewai.com/how-to/Force-Tool-Ouput-as-Result/
# https://docs.crewai.com/how-to/Human-Input-on-Execution/
# https://docs.crewai.com/how-to/Kickoff-async/
# https://docs.crewai.com/how-to/Kickoff-for-each/
# https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff/
# https://docs.crewai.com/how-to/Conditional-Tasks/
# https://docs.crewai.com/how-to/AgentOps-Observability/
# https://docs.crewai.com/how-to/Langtrace-Observability/
# https://docs.crewai.com/tools/SerperDevTool/
# https://docs.crewai.com/tools/BrowserbaseLoadTool/
# https://docs.crewai.com/tools/ComposioTool/
# https://docs.crewai.com/tools/CodeInterpreterTool/
# https://docs.crewai.com/tools/ScrapeWebsiteTool/
# https://docs.crewai.com/tools/DirectoryReadTool/
# https://docs.crewai.com/tools/EXASearchTool/
# https://docs.crewai.com/tools/FileReadTool/
# https://docs.crewai.com/tools/SeleniumScrapingTool/
# https://docs.crewai.com/tools/DirectorySearchTool/
# https://docs.crewai.com/tools/PDFSearchTool/
# https://docs.crewai.com/tools/TXTSearchTool/
# https://docs.crewai.com/tools/CSVSearchTool/
# https://docs.crewai.com/tools/XMLSearchTool/
# https://docs.crewai.com/tools/JSONSearchTool/
# https://docs.crewai.com/tools/DOCXSearchTool/
# https://docs.crewai.com/tools/MDXSearchTool/
# https://docs.crewai.com/tools/PGSearchTool/
# https://docs.crewai.com/tools/WebsiteSearchTool/
# https://docs.crewai.com/tools/GitHubSearchTool/
# https://docs.crewai.com/tools/CodeDocsSearchTool/
# https://docs.crewai.com/tools/YoutubeVideoSearchTool/
# https://docs.crewai.com/tools/YoutubeChannelSearchTool/
# https://github.com/joaomdmoura/crewAI-examples/tree/main/trip_planner
# https://github.com/joaomdmoura/crewAI-examples/tree/main/instagram_post
# https://github.com/joaomdmoura/crewAI-examples/tree/main/stock_analysis
# https://github.com/joaomdmoura/crewAI-examples/tree/main/game-builder-crew
# https://github.com/joaomdmoura/crewAI-examples/tree/main/CrewAI-LangGraph
# https://github.com/joaomdmoura/crewAI-examples/tree/main/landing_page_generator
# https://github.com/joaomdmoura/crewAI-examples/tree/main/prep-for-a-meeting
# https://docs.crewai.com/telemetry/Telemetry/
# https://github.com/crewAIInc/crewAI/releases
# https://github.com/joaomdmoura/crewai/edit/main/docs/index.md
# https://github.com/joaomdmoura/crewai/raw/main/docs/index.md
# https://docs.crewai.com/#crewai-documentation
# https://docs.crewai.com/core-concepts/Agents
# https://docs.crewai.com/core-concepts/Tasks
# https://docs.crewai.com/core-concepts/Tools
# https://docs.crewai.com/core-concepts/Processes
# https://docs.crewai.com/core-concepts/Crews
# https://docs.crewai.com/core-concepts/Training-Crew
# https://docs.crewai.com/core-concepts/Memory
# https://docs.crewai.com/core-concepts/Planning
# https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project
# https://docs.crewai.com/how-to/Installing-CrewAI
# https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off
# https://docs.crewai.com/how-to/Create-Custom-Tools
# https://docs.crewai.com/how-to/Sequential
# https://docs.crewai.com/how-to/Hierarchical
# https://docs.crewai.com/how-to/LLM-Connections
# https://docs.crewai.com/how-to/Customizing-Agents
# https://docs.crewai.com/how-to/Coding-Agents
# https://docs.crewai.com/how-to/Force-Tool-Ouput-as-Result
# https://docs.crewai.com/how-to/Human-Input-on-Execution
# https://docs.crewai.com/how-to/Kickoff-async
# https://docs.crewai.com/how-to/Kickoff-for-each
# https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff
# https://docs.crewai.com/how-to/Conditional-Tasks
# https://docs.crewai.com/how-to/AgentOps-Observability
# https://docs.crewai.com/how-to/Langtrace-Observability
# https://github.com/joaomdmoura/crewAI-examples/tree/main/prep-for-a-meeting
# https://github.com/joaomdmoura/crewAI-examples/tree/main/trip_planner
# https://github.com/joaomdmoura/crewAI-examples/tree/main/instagram_post
# https://github.com/joaomdmoura/crewAI-examples/tree/main/stock_analysis
# https://github.com/joaomdmoura/crewAI-examples/tree/main/game-builder-crew
# https://github.com/joaomdmoura/crewAI-examples/tree/main/CrewAI-LangGraph
# https://github.com/joaomdmoura/crewAI-examples/tree/main/landing_page_generator
# https://squidfunk.github.io/mkdocs-material/
# https://twitter.com/joaomdmoura
# https://github.com/joaomdmoura/crewAI
# 107

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def extract_links(url):
    # Send a request to the website
    response = requests.get(url)
    
    # Parse the content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Use a set to store unique links
    links = set()
    for a_tag in soup.find_all('a', href=True):
        # Resolve relative URLs
        full_url = urljoin(url, a_tag['href'])
        links.add(full_url)
    
    return list(links)

# Example usage
website_url = 'https://docs.crewai.com/'
all_links = extract_links(website_url)

# Print all unique links
for link in all_links:
    print(link)
print(len(all_links))
# Out:
# https://docs.crewai.com/tools/DirectorySearchTool/
# https://docs.crewai.com/tools/ComposioTool/
# https://docs.crewai.com/tools/GitHubSearchTool/
# https://docs.crewai.com/tools/SerperDevTool/
# https://docs.crewai.com/core-concepts/Using-LangChain-Tools/
# https://docs.crewai.com/tools/DOCXSearchTool/
# https://docs.crewai.com/how-to/AgentOps-Observability/
# https://docs.crewai.com/core-concepts/Memory/
# https://docs.crewai.com/core-concepts/Agents/
# https://docs.crewai.com/how-to/Kickoff-for-each/
# https://docs.crewai.com/tools/FileReadTool/
# https://docs.crewai.com/
# https://docs.crewai.com/how-to/Coding-Agents
# https://github.com/joaomdmoura/crewAI-examples/tree/main/trip_planner
# https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off
# https://docs.crewai.com/how-to/Installing-CrewAI/
# https://docs.crewai.com/tools/YoutubeVideoSearchTool/
# https://docs.crewai.com/core-concepts/Training-Crew/
# https://docs.crewai.com/tools/DirectoryReadTool/
# https://docs.crewai.com/core-concepts/Testing/
# https://github.com/joaomdmoura/crewai/edit/main/docs/index.md
# https://docs.crewai.com/core-concepts/Tools
# https://docs.crewai.com/how-to/Hierarchical
# https://github.com/joaomdmoura/crewAI-examples/tree/main/prep-for-a-meeting
# https://docs.crewai.com/core-concepts/Processes/
# https://docs.crewai.com/core-concepts/Tasks
# https://docs.crewai.com/core-concepts/Using-LlamaIndex-Tools/
# https://docs.crewai.com/how-to/Conditional-Tasks
# https://docs.crewai.com/how-to/Langtrace-Observability
# https://docs.crewai.com/core-concepts/Tasks/
# https://docs.crewai.com/how-to/Sequential/
# https://github.com/joaomdmoura/crewAI-examples/tree/main/game-builder-crew
# https://github.com/joaomdmoura/crewAI-examples/tree/main/CrewAI-LangGraph
# https://docs.crewai.com/tools/EXASearchTool/
# https://github.com/joaomdmoura/crewAI
# https://twitter.com/joaomdmoura
# https://docs.crewai.com/core-concepts/Crews/
# https://docs.crewai.com/how-to/Customizing-Agents/
# https://github.com/joaomdmoura/crewAI-examples/tree/main/instagram_post
# https://docs.crewai.com/how-to/Hierarchical/
# https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff/
# https://docs.crewai.com/how-to/Coding-Agents/
# https://docs.crewai.com/tools/PGSearchTool/
# https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project
# https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off/
# https://github.com/crewAIInc/crewAI/releases
# https://docs.crewai.com/core-concepts/Processes
# https://docs.crewai.com/tools/SeleniumScrapingTool/
# https://docs.crewai.com/tools/TXTSearchTool/
# https://squidfunk.github.io/mkdocs-material/
# https://docs.crewai.com/how-to/Kickoff-async
# https://docs.crewai.com/how-to/Human-Input-on-Execution
# https://docs.crewai.com/tools/CodeInterpreterTool/
# https://docs.crewai.com/core-concepts/Crews
# https://github.com/joaomdmoura/crewai/
# https://docs.crewai.com/how-to/LLM-Connections/
# https://docs.crewai.com/tools/BrowserbaseLoadTool/
# https://docs.crewai.com/core-concepts/Memory
# https://docs.crewai.com/tools/XMLSearchTool/
# https://docs.crewai.com/core-concepts/Planning/
# https://docs.crewai.com/how-to/Your-Own-Manager-Agent/
# https://docs.crewai.com/tools/YoutubeChannelSearchTool/
# https://github.com/joaomdmoura/crewAI-examples/tree/main/stock_analysis
# https://docs.crewai.com/how-to/Force-Tool-Ouput-as-Result
# https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project/
# https://docs.crewai.com/how-to/LLM-Connections
# https://docs.crewai.com/tools/WebsiteSearchTool/
# https://docs.crewai.com/core-concepts/Collaboration/
# https://github.com/joaomdmoura/crewai/raw/main/docs/index.md
# https://docs.crewai.com/how-to/Installing-CrewAI
# https://docs.crewai.com/how-to/Create-Custom-Tools
# https://docs.crewai.com/how-to/Force-Tool-Ouput-as-Result/
# javascript:void(0)
# https://docs.crewai.com/tools/MDXSearchTool/
# https://docs.crewai.com/#crewai-documentation
# https://docs.crewai.com/how-to/Create-Custom-Tools/
# https://docs.crewai.com/how-to/Customizing-Agents
# https://docs.crewai.com/tools/ScrapeWebsiteTool/
# https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff
# https://github.com/joaomdmoura/crewAI-examples/tree/main/landing_page_generator
# https://docs.crewai.com/tools/JSONSearchTool/
# https://docs.crewai.com/how-to/AgentOps-Observability
# https://docs.crewai.com/core-concepts/Training-Crew
# https://docs.crewai.com/core-concepts/Agents
# https://docs.crewai.com/how-to/Langtrace-Observability/
# https://docs.crewai.com/tools/CSVSearchTool/
# https://docs.crewai.com/how-to/Sequential
# https://docs.crewai.com/core-concepts/Tools/
# https://docs.crewai.com/telemetry/Telemetry/
# https://docs.crewai.com/tools/PDFSearchTool/
# https://docs.crewai.com/how-to/Kickoff-async/
# https://docs.crewai.com/core-concepts/Planning
# https://docs.crewai.com/how-to/Kickoff-for-each
# https://docs.crewai.com/how-to/Conditional-Tasks/
# https://docs.crewai.com/how-to/Human-Input-on-Execution/
# https://docs.crewai.com/tools/CodeDocsSearchTool/
# 96

# %%
def scrape_link_content(url):
    try:
        # Send a request to the link
        response = requests.get(url)
        response.raise_for_status()
        
        # Parse the content with BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract and clean text content
        text = soup.get_text()
        # Remove leading/trailing whitespace and multiple newlines
        cleaned_text = ' '.join(text.split())
        
        return cleaned_text
    except requests.exceptions.RequestException as e:
        print(f"Error scraping {url}: {e}")
        return None

# Example usage
website_url = 'https://docs.crewai.com/'
all_links = extract_links(website_url)
# all_links = ['https://docs.crewai.com/core-concepts/Agents/']

# Scrape each link
scraped_contents = []
for link in all_links:
    print(f"Scraping {link}")
    content = scrape_website(link)
    if content:
        scraped_contents.append({'url': link, 'content': content})

# Print the cleaned scraped content
for item in scraped_contents:
    print(f"URL: {item['url']}")
    print(f"Content: {item['content'][:500]}")  # Print first 500 characters of content
    print('-' * 80)
# Out:
# Scraping https://docs.crewai.com/tools/DirectorySearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/ComposioTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/GitHubSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/SerperDevTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Using-LangChain-Tools/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/DOCXSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/AgentOps-Observability/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Memory/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Agents/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Kickoff-for-each/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/FileReadTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Coding-Agents
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/trip_planner
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Installing-CrewAI/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/YoutubeVideoSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Training-Crew/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/DirectoryReadTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Testing/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewai/edit/main/docs/index.md
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Tools
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Hierarchical
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/prep-for-a-meeting
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Processes/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Tasks
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Using-LlamaIndex-Tools/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Conditional-Tasks
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Langtrace-Observability
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Tasks/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Sequential/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/game-builder-crew
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/CrewAI-LangGraph
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/EXASearchTool/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI
# Using Tool: Read website content
# Scraping https://twitter.com/joaomdmoura
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Crews/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Customizing-Agents/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/instagram_post
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Hierarchical/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Coding-Agents/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/PGSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off/
# Using Tool: Read website content
# Scraping https://github.com/crewAIInc/crewAI/releases
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Processes
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/SeleniumScrapingTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/TXTSearchTool/
# Using Tool: Read website content
# Scraping https://squidfunk.github.io/mkdocs-material/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Kickoff-async
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Human-Input-on-Execution
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/CodeInterpreterTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Crews
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewai/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/LLM-Connections/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/BrowserbaseLoadTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Memory
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/XMLSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Planning/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Your-Own-Manager-Agent/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/YoutubeChannelSearchTool/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/stock_analysis
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Force-Tool-Ouput-as-Result
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/LLM-Connections
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/WebsiteSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Collaboration/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewai/raw/main/docs/index.md
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Installing-CrewAI
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Create-Custom-Tools
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Force-Tool-Ouput-as-Result/
# Using Tool: Read website content
# Scraping javascript:void(0)
# Using Tool: Read website content
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[40], line 29
#      27 for link in all_links:
#      28     print(f"Scraping {link}")
# ---> 29     content = scrape_website(link)
#      30     if content:
#      31         scraped_contents.append({'url': link, 'content': content})
#
# Cell In[27], line 14, in scrape_website(website_url)
#       7 """Scrapes all the information from the given website.
#       8 Args:
#       9     website_url: A url of a company website.
#      10 Returns:
#      11     Scraped information from the given website.
#      12 """
#      13 scrapper = ScrapeWebsiteTool()
# ---> 14 data = scrapper.run(website_url=website_url)
#      16 return data
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\crewai_tools\tools\base_tool.py:52, in BaseTool.run(self, *args, **kwargs)
#      46 def run(
#      47     self,
#      48     *args: Any,
#      49     **kwargs: Any,
#      50 ) -> Any:
#      51     print(f"Using Tool: {self.name}")
# ---> 52     return self._run(*args, **kwargs)
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\crewai_tools\tools\scrape_website_tool\scrape_website_tool.py:47, in ScrapeWebsiteTool._run(self, **kwargs)
#      42 def _run(
#      43 	self,
#      44 	**kwargs: Any,
#      45 ) -> Any:
#      46 	website_url = kwargs.get('website_url', self.website_url)
# ---> 47 	page = requests.get(
#      48 		website_url,
#      49 		timeout=15,
#      50 		headers=self.headers,
#      51 		cookies=self.cookies if self.cookies else {}
#      52 	)
#      53 	parsed = BeautifulSoup(page.content, "html.parser")
#      54 	text = parsed.get_text()
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\requests\sessions.py:697, in Session.send(self, request, **kwargs)
#     694 hooks = request.hooks
#     696 # Get the appropriate adapter to use
# --> 697 adapter = self.get_adapter(url=request.url)
#     699 # Start time (approximately) of the request
#     700 start = preferred_clock()
#
# File c:\Users\prudh\anaconda3\envs\gen_ai1\lib\site-packages\requests\sessions.py:794, in Session.get_adapter(self, url)
#     791         return adapter
#     793 # Nothing matches :-/
# --> 794 raise InvalidSchema(f"No connection adapters were found for {url!r}")
#
# InvalidSchema: No connection adapters were found for 'javascript:void(0)'

# %%
len(scraped_contents[0]['content'].split(' '))
# Out:
# 1634

# %%
scraped_contents[2]['url']
print(scraped_contents[2]['content'])
# Out:
# crewAI-examples/trip_planner at main · crewAIInc/crewAI-examples · GitHub
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#  Plan and track work
# Discussions
#  Collaborate outside of code
# Explore
#  All features
#  Documentation
#  GitHub Skills
#  Blog
#  Solutions
# By size
#  Enterprise
#  Teams
#  Startups
# By industry
#  Healthcare
#  Financial services
#  Manufacturing
# By use case
#  CI/CD & Automation
#  DevOps
#  DevSecOps
#  Resources
# Topics
#  AI
#  DevOps
#  Security
#  Software Development
# Explore
#  Learning Pathways
#  White papers, Ebooks, Webinars
#  Customer Stories
#  Partners
#  Open Source
# GitHub Sponsors
#  Fund open source developers
# The ReadME Project
#  GitHub community articles
# Repositories
#  Topics
#  Trending
#  Collections
#  Enterprise
# Enterprise platform
#  AI-powered developer platform
# Available add-ons
# Advanced Security
#  Enterprise-grade security features
# GitHub Copilot
#  Enterprise-grade AI features
# Premium Support
#  Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
#  Search
# Clear
#  Search syntax tips
#  Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
#  Cancel
#  Submit feedback
#  Saved searches
# Use saved searches to filter your results more quickly
# Name
# Query
#  To see all available qualifiers, see our documentation.
#  Cancel
#  Create saved search
#  Sign in
#  Sign up
# You signed in with another tab or window. Reload to refresh your session.
# You signed out in another tab or window. Reload to refresh your session.
# You switched accounts on another tab or window. Reload to refresh your session.
# Dismiss alert
#  crewAIInc
# /
# crewAI-examples
# Public
# Notifications
#  You must be signed in to change notification settings
# Fork
#  851
#  Star
#  2.4k
# Code
# Issues
# 48
# Pull requests
# 43
# Actions
# Projects
# 0
# Security
# Insights
# Additional navigation options
#  Code
#  Issues
#  Pull requests
#  Actions
#  Projects
#  Security
#  Insights
#  Files mainBreadcrumbscrewAI-examples/trip_planner/Directory actionsMore optionsDirectory actionsMore optionsLatest commit HistoryHistory mainBreadcrumbscrewAI-examples/trip_planner/TopFolders and filesNameNameLast commit messageLast commit dateparent directory..toolstools  .env.example.env.example  .gitignore.gitignore  README.mdREADME.md  main.pymain.py  poetry.lockpoetry.lock  pyproject.tomlpyproject.toml  trip_agents.pytrip_agents.py  trip_tasks.pytrip_tasks.py  View all filesREADME.mdAI Crew for Trip Planning
# Introduction
# This project is an example using the CrewAI framework to automate the process of planning a trip if you are in doubt between different options. CrewAI orchestrates autonomous AI agents, enabling them to collaborate and execute complex tasks efficiently.
# By @joaomdmoura
# CrewAI Framework
# Running the script
# Details & Explanation
# Using GPT 3.5
# Using Local Models with Ollama
# Contributing
# Support and Contact
# License
# CrewAI Framework
# CrewAI is designed to facilitate the collaboration of role-playing AI agents. In this example, these agents work together to choose between different of cities and put together a full itinerary for the trip based on your preferences.
# Running the Script
# It uses GPT-4 by default so you should have access to that to run it.
# Disclaimer: This will use gpt-4 unless you changed it
# not to, and by doing so it will cost you money.
# Configure Environment: Copy ``.env.example` and set up the environment variables for Browseless, Serper and OpenAI
# Install Dependencies: Run poetry install --no-root.
# Execute the Script: Run poetry run python main.py and input your idea.
# Details & Explanation
# Running the Script: Execute `python main.py`` and input your idea when prompted. The script will leverage the CrewAI framework to process the idea and generate a landing page.
# Key Components:
# ./main.py: Main script file.
# ./trip_tasks.py: Main file with the tasks prompts.
# ./trip_agents.py: Main file with the agents creation.
# ./tools: Contains tool classes used by the agents.
# Using GPT 3.5
# CrewAI allow you to pass an llm argument to the agent construtor, that will be it's brain, so changing the agent to use GPT-3.5 instead of GPT-4 is as simple as passing that argument on the agent you want to use that LLM (in main.py).
# from langchain.chat_models import ChatOpenAI
# llm = ChatOpenAI(model='gpt-3.5') # Loading GPT-3.5
# def local_expert(self):
# 	return Agent(
# 		role='Local Expert at this city',
# 		goal='Provide the BEST insights about the selected city',
# 		backstory="""A knowledgeable local guide with extensive information
# 		about the city, it's attractions and customs""",
# 		tools=[
# 			SearchTools.search_internet,
# 			BrowserTools.scrape_and_summarize_website,
# 		],
# 		llm=llm, # <----- passing our llm reference here
# 		verbose=True
# 	)
# Using Local Models with Ollama
# The CrewAI framework supports integration with local models, such as Ollama, for enhanced flexibility and customization. This allows you to utilize your own models, which can be particularly useful for specialized tasks or data privacy concerns.
# Setting Up Ollama
# Install Ollama: Ensure that Ollama is properly installed in your environment. Follow the installation guide provided by Ollama for detailed instructions.
# Configure Ollama: Set up Ollama to work with your local model. You will probably need to tweak the model using a Modelfile, I'd recommend adding Observation as a stop word and playing with top_p and temperature.
# Integrating Ollama with CrewAI
# Instantiate Ollama Model: Create an instance of the Ollama model. You can specify the model and the base URL during instantiation. For example:
# from langchain.llms import Ollama
# ollama_openhermes = Ollama(model="agent")
# # Pass Ollama Model to Agents: When creating your agents within the CrewAI framework, you can pass the Ollama model as an argument to the Agent constructor. For instance:
# def local_expert(self):
# 	return Agent(
# 		role='Local Expert at this city',
# 		goal='Provide the BEST insights about the selected city',
# 		backstory="""A knowledgeable local guide with extensive information
# 		about the city, it's attractions and customs""",
# 		tools=[
# 			SearchTools.search_internet,
# 			BrowserTools.scrape_and_summarize_website,
# 		],
# 		llm=ollama_openhermes, # Ollama model passed here
# 		verbose=True
# 	)
# Advantages of Using Local Models
# Privacy: Local models allow processing of data within your own infrastructure, ensuring data privacy.
# Customization: You can customize the model to better suit the specific needs of your tasks.
# Performance: Depending on your setup, local models can offer performance benefits, especially in terms of latency.
# License
# This project is released under the MIT License.
# Footer
#  © 2024 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
#  Manage cookies
#  Do not share my personal information
#  You can’t perform that action at this time.

# %%
from crewai_tools import ScrapeWebsiteTool

def scrape_website(website_url):
    """Scrapes all the information from the given website.       
    Args:
        website_url: A url of a company website.
    Returns:
        Scraped information from the given website.
    """
    scrapper = ScrapeWebsiteTool()
    data = scrapper.run(website_url=website_url)

    return data

# %%
a = scrape_website('https://docs.crewai.com/how-to/Human-Input-on-Execution/')
# Out:
# Using Tool: Read website content

# %%
print(a)
# Out:
# Human Input on Execution - crewAI
#  Skip to content
#  crewAI
#  Human Input on Execution
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to any LLM
#  Customizing Agents
#  Coding Agents
#  Forcing Tool Output as Result
#  Human Input on Execution
#  Human Input on Execution
#  Table of contents
#  Using Human Input with CrewAI
#  Example:
#  Kickoff a Crew Asynchronously
#  Kickoff a Crew for a List
#  Replay from a specific task from a kickoff
#  Conditional Tasks
#  Agent Monitoring with AgentOps
#  Agent Monitoring with LangTrace
#  Tools Docs
#  Tools Docs
#  Google Serper Search
#  Browserbase Web Loader
#  Composio Tools
#  Code Interpreter
#  Scrape Website
#  Directory Read
#  Exa Serch Web Loader
#  File Read
#  Selenium Scraper
#  Directory RAG Search
#  PDF RAG Search
#  TXT RAG Search
#  CSV RAG Search
#  XML RAG Search
#  JSON RAG Search
#  Docx Rag Search
#  MDX RAG Search
#  PG RAG Search
#  Website RAG Search
#  Github RAG Search
#  Code Docs RAG Search
#  Youtube Video RAG Search
#  Youtube Channel RAG Search
#  Examples
#  Examples
#  Trip Planner Crew
#  Create Instagram Post
#  Stock Analysis
#  Game Generator
#  Drafting emails with LangGraph
#  Landing Page Generator
#  Prepare for meetings
#  Telemetry
#  Change Log
# Human Input in Agent Execution¶
# Human input is critical in several agent execution scenarios, allowing agents to request additional information or clarification when necessary. This feature is especially useful in complex decision-making processes or when agents require more details to complete a task effectively.
# Using Human Input with CrewAI¶
# To integrate human input into agent execution, set the human_input flag in the task definition. When enabled, the agent prompts the user for input before delivering its final answer. This input can provide extra context, clarify ambiguities, or validate the agent's output.
# Example:¶
# pip install crewai
# import os
# from crewai import Agent, Task, Crew
# from crewai_tools import SerperDevTool
# os.environ["SERPER_API_KEY"] = "Your Key" # serper.dev API key
# os.environ["OPENAI_API_KEY"] = "Your Key"
# # Loading Tools
# search_tool = SerperDevTool()
# # Define your agents with roles, goals, tools, and additional attributes
# researcher = Agent(
#  role='Senior Research Analyst',
#  goal='Uncover cutting-edge developments in AI and data science',
#  backstory=(
#  "You are a Senior Research Analyst at a leading tech think tank. "
#  "Your expertise lies in identifying emerging trends and technologies in AI and data science. "
#  "You have a knack for dissecting complex data and presenting actionable insights."
#  ),
#  verbose=True,
#  allow_delegation=False,
#  tools=[search_tool]
# )
# writer = Agent(
#  role='Tech Content Strategist',
#  goal='Craft compelling content on tech advancements',
#  backstory=(
#  "You are a renowned Tech Content Strategist, known for your insightful and engaging articles on technology and innovation. "
#  "With a deep understanding of the tech industry, you transform complex concepts into compelling narratives."
#  ),
#  verbose=True,
#  allow_delegation=True,
#  tools=[search_tool],
#  cache=False, # Disable cache for this agent
# )
# # Create tasks for your agents
# task1 = Task(
#  description=(
#  "Conduct a comprehensive analysis of the latest advancements in AI in 2024. "
#  "Identify key trends, breakthrough technologies, and potential industry impacts. "
#  "Compile your findings in a detailed report. "
#  "Make sure to check with a human if the draft is good before finalizing your answer."
#  ),
#  expected_output='A comprehensive full report on the latest AI advancements in 2024, leave nothing out',
#  agent=researcher,
#  human_input=True
# )
# task2 = Task(
#  description=(
#  "Using the insights from the researcher\'s report, develop an engaging blog post that highlights the most significant AI advancements. "
#  "Your post should be informative yet accessible, catering to a tech-savvy audience. "
#  "Aim for a narrative that captures the essence of these breakthroughs and their implications for the future."
#  ),
#  expected_output='A compelling 3 paragraphs blog post formatted as markdown about the latest AI advancements in 2024',
#  agent=writer
# )
# # Instantiate your crew with a sequential process
# crew = Crew(
#  agents=[researcher, writer],
#  tasks=[task1, task2],
#  verbose=2,
#  memory=True,
# )
# # Get your crew to work!
# result = crew.kickoff()
# print("######################")
# print(result)
#  Back to top
#  Previous
#  Forcing Tool Output as Result
#  Next
#  Kickoff a Crew Asynchronously
#  Copyright © 2024 crewAI, Inc
#  Made with
#  Material for MkDocs

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from crewai_tools import ScrapeWebsiteTool

def scrape_website(website_url):
    """Scrapes all the information from the given website.       
    Args:
        website_url: A url of a company website.
    Returns:
        Scraped information from the given website.
    """
    scrapper = ScrapeWebsiteTool()
    data = scrapper.run(website_url=website_url)

    return data

def extract_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')  
    links = set()
    for a_tag in soup.find_all('a', href=True):
        full_url = urljoin(url, a_tag['href'])
        links.add(full_url)   
    return list(links)

def extract_content(website_url):
    # website_url = 'https://python.langchain.com/v0.2/docs/introduction/'
    all_links = extract_links(website_url)

    scraped_contents = []
    for i, link in enumerate(all_links):
        print(f'link {i}')
        print(f"Scraping {link}")
        try:
            content = scrape_website(link)
        except Exception as e:
            print(e)
        if content:
            scraped_contents.append({'url': link, 'content': content})

    # for item in scraped_contents:
    #     print(f"URL: {item['url']}")
    #     print(f"Content: {item['content'][:500]}")  # Print first 500 characters of content
    #     print('-' * 80)
    return scraped_contents

# %%
content = extract_content('https://docs.crewai.com/')

for item in content:
        print(f"URL: {item['url']}")
        print()
        print(f"Content: {item['content'][:500]}")  # Print first 500 characters of content
        print()
        print('-' * 80)
        print()
# Out:
# Scraping https://docs.crewai.com/tools/DirectorySearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/ComposioTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/GitHubSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/SerperDevTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Using-LangChain-Tools/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/DOCXSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/AgentOps-Observability/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Memory/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Agents/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Kickoff-for-each/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/FileReadTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Coding-Agents
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/trip_planner
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Installing-CrewAI/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/YoutubeVideoSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Training-Crew/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/DirectoryReadTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Testing/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewai/edit/main/docs/index.md
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Tools
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Hierarchical
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/prep-for-a-meeting
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Processes/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Tasks
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Using-LlamaIndex-Tools/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Conditional-Tasks
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Langtrace-Observability
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Tasks/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Sequential/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/game-builder-crew
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/CrewAI-LangGraph
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/EXASearchTool/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI
# Using Tool: Read website content
# Scraping https://twitter.com/joaomdmoura
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Crews/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Customizing-Agents/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/instagram_post
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Hierarchical/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Coding-Agents/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/PGSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off/
# Using Tool: Read website content
# Scraping https://github.com/crewAIInc/crewAI/releases
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Processes
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/SeleniumScrapingTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/TXTSearchTool/
# Using Tool: Read website content
# Scraping https://squidfunk.github.io/mkdocs-material/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Kickoff-async
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Human-Input-on-Execution
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/CodeInterpreterTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Crews
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewai/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/LLM-Connections/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/BrowserbaseLoadTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Memory
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/XMLSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Planning/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Your-Own-Manager-Agent/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/YoutubeChannelSearchTool/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/stock_analysis
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Force-Tool-Ouput-as-Result
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/LLM-Connections
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/WebsiteSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Collaboration/
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewai/raw/main/docs/index.md
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Installing-CrewAI
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Create-Custom-Tools
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Force-Tool-Ouput-as-Result/
# Using Tool: Read website content
# Scraping javascript:void(0)
# Using Tool: Read website content
# No connection adapters were found for 'javascript:void(0)'
# Scraping https://docs.crewai.com/tools/MDXSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/#crewai-documentation
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Create-Custom-Tools/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Customizing-Agents
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/ScrapeWebsiteTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff
# Using Tool: Read website content
# Scraping https://github.com/joaomdmoura/crewAI-examples/tree/main/landing_page_generator
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/JSONSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/AgentOps-Observability
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Training-Crew
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Agents
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Langtrace-Observability/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/CSVSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Sequential
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Tools/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/telemetry/Telemetry/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/PDFSearchTool/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Kickoff-async/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/core-concepts/Planning
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Kickoff-for-each
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Conditional-Tasks/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/how-to/Human-Input-on-Execution/
# Using Tool: Read website content
# Scraping https://docs.crewai.com/tools/CodeDocsSearchTool/
# Using Tool: Read website content
# URL: https://docs.crewai.com/tools/DirectorySearchTool/
#
# Content: Directory RAG Search - crewAI
#  Skip to content
#  crewAI
#  Directory RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/ComposioTool/
#
# Content: Composio Tools - crewAI
#  Skip to content
#  crewAI
#  Composio Tools
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting t
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/GitHubSearchTool/
#
# Content: Github RAG Search - crewAI
#  Skip to content
#  crewAI
#  Github RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connec
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/SerperDevTool/
#
# Content: Google Serper Search - crewAI
#  Skip to content
#  crewAI
#  Google Serper Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Using-LangChain-Tools/
#
# Content: Using LangChain Tools - crewAI
#  Skip to content
#  crewAI
#  Using LangChain Tools
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LangChain Tools
#  Table of contents
#  Using LangChain Tools
#  Conclusion
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/DOCXSearchTool/
#
# Content: Docx Rag Search - crewAI
#  Skip to content
#  crewAI
#  Docx Rag Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/AgentOps-Observability/
#
# Content: Agent Monitoring with AgentOps - crewAI
#  Skip to content
#  crewAI
#  Agent Monitoring with AgentOps
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Memory/
#
# Content: crewAI Memory Systems - crewAI
#  Skip to content
#  crewAI
#  crewAI Memory Systems
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Memory
#  Table of contents
#  Introduction to Memory Systems in crewAI
#  Memory System Components
#  How Memory Systems Empower Agents
#  Implementing Memory in Your Crew
#  Example: Configuring Memory for a Crew
#  Additional Embedding Providers
#  Using OpenAI embeddings (alrea
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Agents/
#
# Content: crewAI Agents - crewAI
#  Skip to content
#  crewAI
#  crewAI Agents
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Agents
#  Table of contents
#  What is an Agent?
#  Agent Attributes
#  Creating an Agent
#  Setting prompt templates
#  Bring your Third Party Agents
#  Conclusion
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Inst
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Kickoff-for-each/
#
# Content: Kickoff For Each - crewAI
#  Skip to content
#  crewAI
#  Kickoff For Each
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecti
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/FileReadTool/
#
# Content: File Read - crewAI
#  Skip to content
#  crewAI
#  File Read
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to any LLM
#
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/
#
# Content: crewAI
#  Skip to content
#  crewAI
#  Home
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to any LLM
#  Customizing Agen
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Coding-Agents
#
# Content: Coding Agents - crewAI
#  Skip to content
#  crewAI
#  Coding Agents
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewAI-examples/tree/main/trip_planner
#
# Content: crewAI-examples/trip_planner at main · crewAIInc/crewAI-examples · GitHub
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#  Plan and track work
# Discussions
#  Collaborate outside of code
# Explore
#  All features
#  Documentation
#  GitHub Skills
#  Blog
#  Solutions
# By
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off
#
# Content: Assembling and Activating Your CrewAI Team - crewAI
#  Skip to content
#  crewAI
#  Assembling and Activating Your CrewAI Team
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Getting Started
#  Table of contents
#  Introduction
#  Step 0: Inst
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Installing-CrewAI/
#
# Content: Installing crewAI - crewAI
#  Skip to content
#  crewAI
#  Installing crewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Installing CrewAI
#  Table of contents
#  Installation
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarc
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/YoutubeVideoSearchTool/
#
# Content: Youtube Video RAG Search - crewAI
#  Skip to content
#  crewAI
#  Youtube Video RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Training-Crew/
#
# Content: crewAI Train - crewAI
#  Skip to content
#  crewAI
#  crewAI Train
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Training
#  Table of contents
#  Introduction
#  Training Your Crew Using the CLI
#  Training Your Crew Programmatically
#  Key Points to Note:
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Gett
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/DirectoryReadTool/
#
# Content: Directory Read - crewAI
#  Skip to content
#  crewAI
#  Directory Read
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting t
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Testing/
#
# Content: crewAI Testing - crewAI
#  Skip to content
#  crewAI
#  crewAI Testing
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Testing
#  Table of contents
#  Introduction
#  Using the Testing Feature
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Us
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewai/edit/main/docs/index.md
#
# Content: Sign in to GitHub · GitHub
# Skip to content
# You signed in with another tab or window. Reload to refresh your session.
# You signed out in another tab or window. Reload to refresh your session.
# You switched accounts on another tab or window. Reload to refresh your session.
# Dismiss alert
# Sign in to GitHub
#  Username or email address
#  Password
# Forgot password?
# Password login alternatives
# Sign in with a passkey
#  New to GitHub?
#  Create an account
# Terms
# Privacy
# Docs
# Contact GitHub Support
#  Manage cookies
#
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Tools
#
# Content: crewAI Tools - crewAI
#  Skip to content
#  crewAI
#  crewAI Tools
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Tools
#  Table of contents
#  Introduction
#  What is a Tool?
#  Key Characteristics of Tools
#  Using crewAI Tools
#  Available crewAI Tools
#  Creating your own Tools
#  Subclassing BaseTool
#  Utilizing the tool Decorator
#  Custom Caching Mechanism
#  Conclusion
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Too
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Hierarchical
#
# Content: Implementing the Hierarchical Process in CrewAI - crewAI
#  Skip to content
#  crewAI
#  Implementing the Hierarchical Process in CrewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewAI-examples/tree/main/prep-for-a-meeting
#
# Content: crewAI-examples/prep-for-a-meeting at main · crewAIInc/crewAI-examples · GitHub
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#  Plan and track work
# Discussions
#  Collaborate outside of code
# Explore
#  All features
#  Documentation
#  GitHub Skills
#  Blog
#  Solutio
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Processes/
#
# Content: Managing Processes in CrewAI - crewAI
#  Skip to content
#  crewAI
#  Managing Processes in CrewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Processes
#  Table of contents
#  Understanding Processes
#  Process Implementations
#  The Role of Processes in Teamwork
#  Assigning Processes to a Crew
#  Sequential Process
#  Hierarchical Process
#  Process Class: Detailed Overview
#  Additional Task Features
#  Conclusion
#  Crews
#  Collaboration
#  Training
#
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Tasks
#
# Content: crewAI Tasks - crewAI
#  Skip to content
#  crewAI
#  crewAI Tasks
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tasks
#  Table of contents
#  Overview of a Task
#  Task Attributes
#  Creating a Task
#  Task Output
#  Task Output Attributes
#  Task Output Methods and Properties
#  Accessing Task Outputs
#  Example
#  Integrating Tools with Tasks
#  Creating a Task with Tools
#  Referring to Other Tasks
#  Asynchronous Execution
#  Callback Mechanism
#  Accessing a Specific Task Ou
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Using-LlamaIndex-Tools/
#
# Content: Using LlamaIndex Tools - crewAI
#  Skip to content
#  crewAI
#  Using LlamaIndex Tools
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  Using LlamaIndex Tools
#  Table of contents
#  Using LlamaIndex Tools
#  Steps to Get Started
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Conditional-Tasks
#
# Content: Conditional Tasks - crewAI
#  Skip to content
#  crewAI
#  Conditional Tasks
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connec
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Langtrace-Observability
#
# Content: CrewAI Agent Monitoring with Langtrace - crewAI
#  Skip to content
#  crewAI
#  CrewAI Agent Monitoring with Langtrace
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Proc
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Tasks/
#
# Content: crewAI Tasks - crewAI
#  Skip to content
#  crewAI
#  crewAI Tasks
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tasks
#  Table of contents
#  Overview of a Task
#  Task Attributes
#  Creating a Task
#  Task Output
#  Task Output Attributes
#  Task Output Methods and Properties
#  Accessing Task Outputs
#  Example
#  Integrating Tools with Tasks
#  Creating a Task with Tools
#  Referring to Other Tasks
#  Asynchronous Execution
#  Callback Mechanism
#  Accessing a Specific Task Ou
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Sequential/
#
# Content: Using the Sequential Processes in crewAI - crewAI
#  Skip to content
#  crewAI
#  Using the Sequential Processes in crewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Sequential Pr
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewAI-examples/tree/main/game-builder-crew
#
# Content: crewAI-examples/game-builder-crew at main · crewAIInc/crewAI-examples · GitHub
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#  Plan and track work
# Discussions
#  Collaborate outside of code
# Explore
#  All features
#  Documentation
#  GitHub Skills
#  Blog
#  Solution
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewAI-examples/tree/main/CrewAI-LangGraph
#
# Content: crewAI-examples/CrewAI-LangGraph at main · crewAIInc/crewAI-examples · GitHub
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#  Plan and track work
# Discussions
#  Collaborate outside of code
# Explore
#  All features
#  Documentation
#  GitHub Skills
#  Blog
#  Solutions
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/EXASearchTool/
#
# Content: Exa Serch Web Loader - crewAI
#  Skip to content
#  crewAI
#  Exa Serch Web Loader
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewAI
#
# Content: GitHub - crewAIInc/crewAI: Framework for orchestrating role-playing, autonomous AI agents. By fostering collaborative intelligence, CrewAI empowers agents to work together seamlessly, tackling complex tasks.
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#
#
# --------------------------------------------------------------------------------
#
# URL: https://twitter.com/joaomdmoura
#
# Content: x.com
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Crews/
#
# Content: crewAI Crews - crewAI
#  Skip to content
#  crewAI
#  crewAI Crews
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Crews
#  Table of contents
#  What is a Crew?
#  Crew Attributes
#  Creating a Crew
#  Example: Assembling a Crew
#  Crew Output
#  Crew Output Attributes
#  Crew Output Methods and Properties
#  Accessing Crew Outputs
#  Example
#  Memory Utilization
#  Cache Utilization
#  Crew Usage Metrics
#  Crew Execution Process
#  Kicking Off a Crew
#  Dif
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Customizing-Agents/
#
# Content: Customizing Agents in CrewAI - crewAI
#  Skip to content
#  crewAI
#  Customizing Agents in CrewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewAI-examples/tree/main/instagram_post
#
# Content: crewAI-examples/instagram_post at main · crewAIInc/crewAI-examples · GitHub
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#  Plan and track work
# Discussions
#  Collaborate outside of code
# Explore
#  All features
#  Documentation
#  GitHub Skills
#  Blog
#  Solutions
# B
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Hierarchical/
#
# Content: Implementing the Hierarchical Process in CrewAI - crewAI
#  Skip to content
#  crewAI
#  Implementing the Hierarchical Process in CrewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff/
#
# Content: Replay Tasks from Latest Crew Kickoff - crewAI
#  Skip to content
#  crewAI
#  Replay Tasks from Latest Crew Kickoff
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Proces
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Coding-Agents/
#
# Content: Coding Agents - crewAI
#  Skip to content
#  crewAI
#  Coding Agents
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/PGSearchTool/
#
# Content: PG RAG Search - crewAI
#  Skip to content
#  crewAI
#  PG RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Start-a-New-CrewAI-Project
#
# Content: Starting a New CrewAI Project - crewAI
#  Skip to content
#  crewAI
#  Starting a New CrewAI Project
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Starting Your crewAI Project
#  Table of contents
#  Prerequisites
#  Creating a New Project
#  Customizing Your Project
#  Example: D
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off/
#
# Content: Assembling and Activating Your CrewAI Team - crewAI
#  Skip to content
#  crewAI
#  Assembling and Activating Your CrewAI Team
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Getting Started
#  Table of contents
#  Introduction
#  Step 0: Inst
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/crewAIInc/crewAI/releases
#
# Content: Releases · crewAIInc/crewAI · GitHub
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#  Plan and track work
# Discussions
#  Collaborate outside of code
# Explore
#  All features
#  Documentation
#  GitHub Skills
#  Blog
#  Solutions
# By size
#  Enterprise
#  Teams
#  Startups
# By
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Processes
#
# Content: Managing Processes in CrewAI - crewAI
#  Skip to content
#  crewAI
#  Managing Processes in CrewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Processes
#  Table of contents
#  Understanding Processes
#  Process Implementations
#  The Role of Processes in Teamwork
#  Assigning Processes to a Crew
#  Sequential Process
#  Hierarchical Process
#  Process Class: Detailed Overview
#  Additional Task Features
#  Conclusion
#  Crews
#  Collaboration
#  Training
#
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/SeleniumScrapingTool/
#
# Content: Selenium Scraper - crewAI
#  Skip to content
#  crewAI
#  Selenium Scraper
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecti
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/TXTSearchTool/
#
# Content: TXT RAG Search - crewAI
#  Skip to content
#  crewAI
#  TXT RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting t
#
# --------------------------------------------------------------------------------
#
# URL: https://squidfunk.github.io/mkdocs-material/
#
# Content: Material for MkDocs Material for MkDocs Material for MkDocs Initializing search squidfunk/mkdocs-material Home Getting started Setup Plugins Reference Insiders Community Blog Documentation that simply works Write your documentation in Markdown and create a professional static site in minutes – searchable, customizable, in 60+ languages, for all devices. Get started Learn more © BewilderedBird Everything you would expect ¶ It's just Markdown Focus on the content of your documentation and create a
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Kickoff-async
#
# Content: Kickoff Async - crewAI
#  Skip to content
#  crewAI
#  Kickoff Async
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Human-Input-on-Execution
#
# Content: Human Input on Execution - crewAI
#  Skip to content
#  crewAI
#  Human Input on Execution
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/CodeInterpreterTool/
#
# Content: Code Interpreter - crewAI
#  Skip to content
#  crewAI
#  Code Interpreter
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecti
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Crews
#
# Content: crewAI Crews - crewAI
#  Skip to content
#  crewAI
#  crewAI Crews
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Crews
#  Table of contents
#  What is a Crew?
#  Crew Attributes
#  Creating a Crew
#  Example: Assembling a Crew
#  Crew Output
#  Crew Output Attributes
#  Crew Output Methods and Properties
#  Accessing Crew Outputs
#  Example
#  Memory Utilization
#  Cache Utilization
#  Crew Usage Metrics
#  Crew Execution Process
#  Kicking Off a Crew
#  Dif
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewai/
#
# Content: GitHub - crewAIInc/crewAI: Framework for orchestrating role-playing, autonomous AI agents. By fostering collaborative intelligence, CrewAI empowers agents to work together seamlessly, tackling complex tasks.
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/LLM-Connections/
#
# Content: Connect CrewAI to LLMs - crewAI
#  Skip to content
#  crewAI
#  Connect CrewAI to LLMs
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Age
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/BrowserbaseLoadTool/
#
# Content: Browserbase Web Loader - crewAI
#  Skip to content
#  crewAI
#  Browserbase Web Loader
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Age
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Memory
#
# Content: crewAI Memory Systems - crewAI
#  Skip to content
#  crewAI
#  crewAI Memory Systems
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Memory
#  Table of contents
#  Introduction to Memory Systems in crewAI
#  Memory System Components
#  How Memory Systems Empower Agents
#  Implementing Memory in Your Crew
#  Example: Configuring Memory for a Crew
#  Additional Embedding Providers
#  Using OpenAI embeddings (alrea
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/XMLSearchTool/
#
# Content: XML RAG Search - crewAI
#  Skip to content
#  crewAI
#  XML RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting t
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Planning/
#
# Content: crewAI Planning - crewAI
#  Skip to content
#  crewAI
#  crewAI Planning
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Planning
#  Table of contents
#  Introduction
#  Using the Planning Feature
#  Planning LLM
#  Example
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  U
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Your-Own-Manager-Agent/
#
# Content: Setting a Specific Agent as Manager in CrewAI - crewAI
#  Skip to content
#  crewAI
#  Setting a Specific Agent as Manager in CrewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
# ...
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your o
#
# --------------------------------------------------------------------------------
#
# URL: javascript:void(0)
#
# Content: Forcing Tool Output as Result - crewAI
#  Skip to content
#  crewAI
#  Forcing Tool Output as Result
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your o
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/MDXSearchTool/
#
# Content: MDX RAG Search - crewAI
#  Skip to content
#  crewAI
#  MDX RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting t
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/#crewai-documentation
#
# Content: crewAI
#  Skip to content
#  crewAI
#  Home
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to any LLM
#  Customizing Agen
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Create-Custom-Tools/
#
# Content: Creating and Utilizing Tools in crewAI - crewAI
#  Skip to content
#  crewAI
#  Creating and Utilizing Tools in crewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Create Custom Tools
#  Table of contents
#  Creating
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Customizing-Agents
#
# Content: Customizing Agents in CrewAI - crewAI
#  Skip to content
#  crewAI
#  Customizing Agents in CrewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/ScrapeWebsiteTool/
#
# Content: Scrape Website - crewAI
#  Skip to content
#  crewAI
#  Scrape Website
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting t
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Replay-tasks-from-latest-Crew-Kickoff
#
# Content: Replay Tasks from Latest Crew Kickoff - crewAI
#  Skip to content
#  crewAI
#  Replay Tasks from Latest Crew Kickoff
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Proces
#
# --------------------------------------------------------------------------------
#
# URL: https://github.com/joaomdmoura/crewAI-examples/tree/main/landing_page_generator
#
# Content: crewAI-examples/landing_page_generator at main · crewAIInc/crewAI-examples · GitHub
# Skip to content
# Navigation Menu
# Toggle navigation
#  Sign in
#  Product
# Actions
#  Automate any workflow
# Packages
#  Host and manage packages
# Security
#  Find and fix vulnerabilities
# Codespaces
#  Instant dev environments
# GitHub Copilot
#  Write better code with AI
# Code review
#  Manage code changes
# Issues
#  Plan and track work
# Discussions
#  Collaborate outside of code
# Explore
#  All features
#  Documentation
#  GitHub Skills
#  Blog
#  Sol
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/JSONSearchTool/
#
# Content: JSON RAG Search - crewAI
#  Skip to content
#  crewAI
#  JSON RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/AgentOps-Observability
#
# Content: Agent Monitoring with AgentOps - crewAI
#  Skip to content
#  crewAI
#  Agent Monitoring with AgentOps
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Training-Crew
#
# Content: crewAI Train - crewAI
#  Skip to content
#  crewAI
#  crewAI Train
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Training
#  Table of contents
#  Introduction
#  Training Your Crew Using the CLI
#  Training Your Crew Programmatically
#  Key Points to Note:
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Gett
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Agents
#
# Content: crewAI Agents - crewAI
#  Skip to content
#  crewAI
#  crewAI Agents
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Agents
#  Table of contents
#  What is an Agent?
#  Agent Attributes
#  Creating an Agent
#  Setting prompt templates
#  Bring your Third Party Agents
#  Conclusion
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Inst
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Langtrace-Observability/
#
# Content: CrewAI Agent Monitoring with Langtrace - crewAI
#  Skip to content
#  crewAI
#  CrewAI Agent Monitoring with Langtrace
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Proc
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/CSVSearchTool/
#
# Content: CSV RAG Search - crewAI
#  Skip to content
#  crewAI
#  CSV RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting t
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Sequential
#
# Content: Using the Sequential Processes in crewAI - crewAI
#  Skip to content
#  crewAI
#  Using the Sequential Processes in crewAI
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Sequential Pr
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Tools/
#
# Content: crewAI Tools - crewAI
#  Skip to content
#  crewAI
#  crewAI Tools
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Tools
#  Table of contents
#  Introduction
#  What is a Tool?
#  Key Characteristics of Tools
#  Using crewAI Tools
#  Available crewAI Tools
#  Creating your own Tools
#  Subclassing BaseTool
#  Utilizing the tool Decorator
#  Custom Caching Mechanism
#  Conclusion
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Too
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/telemetry/Telemetry/
#
# Content: Telemetry - crewAI
#  Skip to content
#  crewAI
#  Telemetry
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to any LLM
#
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/PDFSearchTool/
#
# Content: PDF RAG Search - crewAI
#  Skip to content
#  crewAI
#  PDF RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting t
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Kickoff-async/
#
# Content: Kickoff Async - crewAI
#  Skip to content
#  crewAI
#  Kickoff Async
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/core-concepts/Planning
#
# Content: crewAI Planning - crewAI
#  Skip to content
#  crewAI
#  crewAI Planning
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Planning
#  Table of contents
#  Introduction
#  Using the Planning Feature
#  Planning LLM
#  Example
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  U
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Kickoff-for-each
#
# Content: Kickoff For Each - crewAI
#  Skip to content
#  crewAI
#  Kickoff For Each
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecti
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Conditional-Tasks/
#
# Content: Conditional Tasks - crewAI
#  Skip to content
#  crewAI
#  Conditional Tasks
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connec
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/how-to/Human-Input-on-Execution/
#
# Content: Human Input on Execution - crewAI
#  Skip to content
#  crewAI
#  Human Input on Execution
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager
#
# --------------------------------------------------------------------------------
#
# URL: https://docs.crewai.com/tools/CodeDocsSearchTool/
#
# Content: Code Docs RAG Search - crewAI
#  Skip to content
#  crewAI
#  Code Docs RAG Search
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#
#
# --------------------------------------------------------------------------------

# %%
len(content)
# Out:
# 96

# %%
print(content[65]['content'])
# Out:
# Connect CrewAI to LLMs - crewAI
#  Skip to content
#  crewAI
#  Connect CrewAI to LLMs
#  Initializing search
#  crewAI
#  crewAI
#  crewAI
#  Home
#  Core Concepts
#  Core Concepts
#  Agents
#  Tasks
#  Tools
#  Processes
#  Crews
#  Collaboration
#  Training
#  Memory
#  Planning
#  Testing
#  Using LangChain Tools
#  Using LlamaIndex Tools
#  How to Guides
#  How to Guides
#  Starting Your crewAI Project
#  Installing CrewAI
#  Getting Started
#  Create Custom Tools
#  Using Sequential Process
#  Using Hierarchical Process
#  Create your own Manager Agent
#  Connecting to any LLM
#  Connecting to any LLM
#  Table of contents
#  Connect CrewAI to LLMs
#  CrewAI Agent Overview
#  Ollama Integration
#  Setting Up Ollama
#  Ollama Integration (ex. for using Llama 2 locally)
#  HuggingFace Integration
#  Your own HuggingFace endpoint
#  From HuggingFaceHub endpoint
#  OpenAI Compatible API Endpoints
#  Configuration Examples
#  FastChat
#  LM Studio
#  Groq API
#  Mistral API
#  Solar
#  text-gen-web-ui
#  Cohere
#  Azure Open AI Configuration
#  Example Agent with Azure LLM
#  Conclusion
#  Customizing Agents
#  Coding Agents
#  Forcing Tool Output as Result
#  Human Input on Execution
#  Kickoff a Crew Asynchronously
#  Kickoff a Crew for a List
#  Replay from a specific task from a kickoff
#  Conditional Tasks
#  Agent Monitoring with AgentOps
#  Agent Monitoring with LangTrace
#  Tools Docs
#  Tools Docs
#  Google Serper Search
#  Browserbase Web Loader
#  Composio Tools
#  Code Interpreter
#  Scrape Website
#  Directory Read
#  Exa Serch Web Loader
#  File Read
#  Selenium Scraper
#  Directory RAG Search
#  PDF RAG Search
#  TXT RAG Search
#  CSV RAG Search
#  XML RAG Search
#  JSON RAG Search
#  Docx Rag Search
#  MDX RAG Search
#  PG RAG Search
#  Website RAG Search
#  Github RAG Search
#  Code Docs RAG Search
#  Youtube Video RAG Search
#  Youtube Channel RAG Search
#  Examples
#  Examples
#  Trip Planner Crew
#  Create Instagram Post
#  Stock Analysis
#  Game Generator
#  Drafting emails with LangGraph
#  Landing Page Generator
#  Prepare for meetings
#  Telemetry
#  Change Log
# Connecting to any LLM
# Connect CrewAI to LLMs¶
# Default LLM
# By default, CrewAI uses OpenAI's GPT-4 model (specifically, the model specified by the OPENAI_MODEL_NAME environment variable, defaulting to "gpt-4o") for language processing. You can configure your agents to use a different model or API as described in this guide.
# CrewAI offers flexibility in connecting to various LLMs, including local models via Ollama and different APIs like Azure. It's compatible with all LangChain LLM components, enabling diverse integrations for tailored AI solutions.
# CrewAI Agent Overview¶
# The Agent class is the cornerstone for implementing AI solutions in CrewAI. Here's a comprehensive overview of the Agent class attributes and methods:
# Attributes:
# role: Defines the agent's role within the solution.
# goal: Specifies the agent's objective.
# backstory: Provides a background story to the agent.
# cache Optional: Determines whether the agent should use a cache for tool usage. Default is True.
# max_rpm Optional: Maximum number of requests per minute the agent's execution should respect. Optional.
# verbose Optional: Enables detailed logging of the agent's execution. Default is False.
# allow_delegation Optional: Allows the agent to delegate tasks to other agents, default is True.
# tools: Specifies the tools available to the agent for task execution. Optional.
# max_iter Optional: Maximum number of iterations for an agent to execute a task, default is 25.
# max_execution_time Optional: Maximum execution time for an agent to execute a task. Optional.
# step_callback Optional: Provides a callback function to be executed after each step. Optional.
# llm Optional: Indicates the Large Language Model the agent uses. By default, it uses the GPT-4 model defined in the environment variable "OPENAI_MODEL_NAME".
# function_calling_llm Optional : Will turn the ReAct CrewAI agent into a function-calling agent.
# callbacks Optional: A list of callback functions from the LangChain library that are triggered during the agent's execution process.
# system_template Optional: Optional string to define the system format for the agent.
# prompt_template Optional: Optional string to define the prompt format for the agent.
# response_template Optional: Optional string to define the response format for the agent.
# # Required
# os.environ["OPENAI_MODEL_NAME"]="gpt-4-0125-preview"
# # Agent will automatically use the model defined in the environment variable
# example_agent = Agent(
#  role='Local Expert',
#  goal='Provide insights about the city',
#  backstory="A knowledgeable local guide.",
#  verbose=True
# )
# Ollama Integration¶
# Ollama is preferred for local LLM integration, offering customization and privacy benefits. To integrate Ollama with CrewAI, set the appropriate environment variables as shown below.
# Setting Up Ollama¶
# Environment Variables Configuration: To integrate Ollama, set the following environment variables:
# OPENAI_API_BASE='http://localhost:11434'
# OPENAI_MODEL_NAME='llama2' # Adjust based on available model
# OPENAI_API_KEY=''
# Ollama Integration (ex. for using Llama 2 locally)¶
# Download Ollama.
# After setting up the Ollama, Pull the Llama2 by typing following lines into the terminal ollama pull llama2.
# Enjoy your free Llama2 model that powered up by excellent agents from crewai.
# from crewai import Agent, Task, Crew
# from langchain.llms import Ollama
# import os
# os.environ["OPENAI_API_KEY"] = "NA"
# llm = Ollama(
#  model = "llama2",
#  base_url = "http://localhost:11434")
# general_agent = Agent(role = "Math Professor",
#  goal = """Provide the solution to the students that are asking mathematical questions and give them the answer.""",
#  backstory = """You are an excellent math professor that likes to solve math questions in a way that everyone can understand your solution""",
#  allow_delegation = False,
#  verbose = True,
#  llm = llm)
# task = Task(description="""what is 3 + 5""",
#  agent = general_agent,
#  expected_output="A numerical answer.")
# crew = Crew(
#  agents=[general_agent],
#  tasks=[task],
#  verbose=2
#  )
# result = crew.kickoff()
# print(result)
# HuggingFace Integration¶
# There are a couple of different ways you can use HuggingFace to host your LLM.
# Your own HuggingFace endpoint¶
# from langchain_community.llms import HuggingFaceEndpoint
# llm = HuggingFaceEndpoint(
#  endpoint_url="<YOUR_ENDPOINT_URL_HERE>",
#  huggingfacehub_api_token="<HF_TOKEN_HERE>",
#  task="text-generation",
#  max_new_tokens=512
# )
# agent = Agent(
#  role="HuggingFace Agent",
#  goal="Generate text using HuggingFace",
#  backstory="A diligent explorer of GitHub docs.",
#  llm=llm
# )
# From HuggingFaceHub endpoint¶
# from langchain_community.llms import HuggingFaceHub
# llm = HuggingFaceHub(
#  repo_id="HuggingFaceH4/zephyr-7b-beta",
#  huggingfacehub_api_token="<HF_TOKEN_HERE>",
#  task="text-generation",
# )
# OpenAI Compatible API Endpoints¶
# Switch between APIs and models seamlessly using environment variables, supporting platforms like FastChat, LM Studio, Groq, and Mistral AI.
# Configuration Examples¶
# FastChat¶
# OPENAI_API_BASE="http://localhost:8001/v1"
# OPENAI_MODEL_NAME='oh-2.5m7b-q51'
# OPENAI_API_KEY=NA
# LM Studio¶
# Launch LM Studio and go to the Server tab. Then select a model from the dropdown menu and wait for it to load. Once it's loaded, click the green Start Server button and use the URL, port, and API key that's shown (you can modify them). Below is an example of the default settings as of LM Studio 0.2.19:
# OPENAI_API_BASE="http://localhost:1234/v1"
# OPENAI_API_KEY="lm-studio"
# Groq API¶
# OPENAI_API_KEY=your-groq-api-key
# OPENAI_MODEL_NAME='llama3-8b-8192'
# OPENAI_API_BASE=https://api.groq.com/openai/v1
# Mistral API¶
# OPENAI_API_KEY=your-mistral-api-key
# OPENAI_API_BASE=https://api.mistral.ai/v1
# OPENAI_MODEL_NAME="mistral-small"
# Solar¶
# from langchain_community.chat_models.solar import SolarChat
# # Initialize language model
# os.environ["SOLAR_API_KEY"] = "your-solar-api-key"
# llm = SolarChat(max_tokens=1024)
# # Free developer API key available here: https://console.upstage.ai/services/solar
# # Langchain Example: https://github.com/langchain-ai/langchain/pull/18556
# text-gen-web-ui¶
# OPENAI_API_BASE=http://localhost:5000/v1
# OPENAI_MODEL_NAME=NA
# OPENAI_API_KEY=NA
# Cohere¶
# from langchain_cohere import ChatCohere
# # Initialize language model
# os.environ["COHERE_API_KEY"] = "your-cohere-api-key"
# llm = ChatCohere()
# # Free developer API key available here: https://cohere.com/
# # Langchain Documentation: https://python.langchain.com/docs/integrations/chat/cohere
# Azure Open AI Configuration¶
# For Azure OpenAI API integration, set the following environment variables:
# AZURE_OPENAI_VERSION="2022-12-01"
# AZURE_OPENAI_DEPLOYMENT=""
# AZURE_OPENAI_ENDPOINT=""
# AZURE_OPENAI_KEY=""
# Example Agent with Azure LLM¶
# from dotenv import load_dotenv
# from crewai import Agent
# from langchain_openai import AzureChatOpenAI
# load_dotenv()
# azure_llm = AzureChatOpenAI(
#  azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
#  api_key=os.environ.get("AZURE_OPENAI_KEY")
# )
# azure_agent = Agent(
#  role='Example Agent',
#  goal='Demonstrate custom LLM configuration',
#  backstory='A diligent explorer of GitHub docs.',
#  llm=azure_llm
# )
# Conclusion¶
# Integrating CrewAI with different LLMs expands the framework's versatility, allowing for customized, efficient AI solutions across various domains and platforms.
#  Back to top
#  Previous
#  Create your own Manager Agent
#  Next
#  Customizing Agents
#  Copyright © 2024 crewAI, Inc
#  Made with
#  Material for MkDocs
